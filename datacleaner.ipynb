# %%
import pandas as pd
import pandas as np

df = pd.read_csv("SPD_Crime_Data__2008-Present.csv")

df = df.rename(columns={"Report Number": "ReportNumber"})

#print(len(df))
#1033415

df = df.query('ReportNumber.str.contains("2022-") or ReportNumber.str.contains("2023-")', engine='python')

print(len(df))
#76735
# Out:
# 83334

# %%
df.columns
# Out:
# Index(['ReportNumber', 'Offense ID', 'Offense Start DateTime',
#        'Offense End DateTime', 'Report DateTime', 'Group A B',
#        'Crime Against Category', 'Offense Parent Group', 'Offense',
#        'Offense Code', 'Precinct', 'Sector', 'Beat', 'MCPP',
#        '100 Block Address', 'Longitude', 'Latitude'],
#       dtype='object')

# %%
df.head()
# Out:
#        ReportNumber   Offense ID  Offense Start DateTime  \
# 940783  2022-005962  30895317764  01/07/2022 09:40:00 PM
# 940784  2022-005815  30880108291  01/07/2022 12:00:00 AM
# 940785  2022-005857  30869168524  01/06/2022 10:00:00 AM
# 940786  2022-005714  30869478070  01/07/2022 04:19:00 PM
# 940787  2022-005758  30864554663  01/06/2022 09:00:00 PM
#
#           Offense End DateTime         Report DateTime Group A B  \
# 940783                     NaN  01/07/2022 11:02:04 PM         A
# 940784  01/07/2022 07:55:00 PM  01/07/2022 08:58:58 PM         A
# 940785  01/07/2022 07:00:00 PM  01/07/2022 07:36:08 PM         A
# 940786  01/07/2022 04:19:00 PM  01/07/2022 07:31:19 PM         A
# 940787                     NaN  01/07/2022 06:54:44 PM         A
#
#        Crime Against Category   Offense Parent Group  \
# 940783                 PERSON       ASSAULT OFFENSES
# 940784                SOCIETY  WEAPON LAW VIOLATIONS
# 940785               PROPERTY          LARCENY-THEFT
# ...

# %%
df["Offense Parent Group"].value_counts()
# Out:
# LARCENY-THEFT                               31537
# ASSAULT OFFENSES                            12654
# BURGLARY/BREAKING&ENTERING                   9732
# DESTRUCTION/DAMAGE/VANDALISM OF PROPERTY     8097
# MOTOR VEHICLE THEFT                          7875
# FRAUD OFFENSES                               3166
# TRESPASS OF REAL PROPERTY                    2261
# ROBBERY                                      1943
# DRIVING UNDER THE INFLUENCE                  1477
# STOLEN PROPERTY OFFENSES                      977
# WEAPON LAW VIOLATIONS                         911
# DRUG/NARCOTIC OFFENSES                        760
# SEX OFFENSES                                  662
# COUNTERFEITING/FORGERY                        280
# KIDNAPPING/ABDUCTION                          234
# ARSON                                         200
# EXTORTION/BLACKMAIL                           127
